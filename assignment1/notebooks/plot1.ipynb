# %% [markdown]
# Use training dataset.
#
# Do the following:
# 1.1. Make a time variable, x, such that 2018-Jan has x1 = 2018, 2018-Feb has x2 = 2018 + 1/12,
# 2018-Mar has x3 = 2018+2/12 etc. and plot the training data versus x.
# 1.2. Describe the time series in your own words.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../data/train.csv")
print(df)

df["time"] = pd.to_datetime(df["time"], utc=True)
df["x"] = df["time"].dt.year + (df["time"].dt.month - 1 )/12
# Out:
#                          time     total  gasoline   diesel  fgas  ngas  \
# 0   2018-01-01 00:00:00+00:00  2.930483   1781826  1136656    12   256
# 1   2018-02-01 00:00:00+00:00  2.934044   1783338  1138414    12   255
# 2   2018-03-01 00:00:00+00:00  2.941422   1787219  1141576    12   257
# 3   2018-04-01 00:00:00+00:00  2.951498   1793554  1144846    12   257
# 4   2018-05-01 00:00:00+00:00  2.963093   1799795  1149840    12   256
# ..                        ...       ...       ...      ...   ...   ...
# 67  2023-08-01 00:00:00+00:00  3.228835   1851651  1091900    16   552
# 68  2023-09-01 00:00:00+00:00  3.226588   1845911  1084498    16   550
# 69  2023-10-01 00:00:00+00:00  3.220559   1838787  1075629    16   533
# 70  2023-11-01 00:00:00+00:00  3.221920   1835019  1068514    16   533
# 71  2023-12-01 00:00:00+00:00  3.227541   1831941  1062385    16   533
#
#     electricity  petroleum  hydrogen  methanol  ethanol  pluginhybrid  \
# 0          9304          0        81         0        0          2340
# 1          9343          0        80         0        0          2593
# 2          9399          0        77         0        0          2873
# 3          9548          0        77         0        0          3195
# 4          9665          0        77         0        0          3439
# ..          ...        ...       ...       ...      ...           ...
# 67       166046          0       138         0        0        118515
# 68       175592          0        88         0        0        119917
# 69       184125          0        65         0        0        121388
# 70       194948          0        59         0        0        122815
# 71       207888          0        47         0        0        124717
#
#     otherfuels         year
# 0            8  2018.000000
# 1            9  2018.083333
# 2            9  2018.166667
# 3            9  2018.250000
# 4            9  2018.333333
# ..         ...          ...
# 67          17  2023.583333
# 68          16  2023.666667
# 69          16  2023.750000
# 70          16  2023.833333
# 71          14  2023.916667
#
# [72 rows x 14 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(df["x"], df["total"]) # plot total
plt.xlabel("X variable")
plt.ylabel("Total (training data)")
plt.title("Training data vs time variable x")
plt.grid(True)
plt.show()
